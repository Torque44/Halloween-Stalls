# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
df=pd.read_csv("train.csv")

# %%
df
# Out:
#             Product_id  Stall_no             instock_date  Market_Category  \
# 0     BRAE2NF6JA5GUEXG      37.0  2015-08-22 18:36:12.000                2
# 1     TUNE8SFB6RJN2HSD      38.0  2016-03-27 21:19:13.000               24
# 2     BRAEAR7WZPQGPBZU       9.0  2015-08-18 19:25:22.000              447
# 3     WATDZ2ZQ8JPDHCTJ      50.0  2016-03-28 21:53:01.000               23
# 4     JWSEBUKYQPMBZ3RK       7.0  2016-03-29 22:58:53.000               63
# ...                ...       ...                      ...              ...
# 6363  WATE7VE2D62VEKW8      17.0  2016-03-28 19:55:43.000               24
# 6364  SHOEF9G8Z4ZXF6WE      21.0  2015-02-11 15:09:26.000               55
# 6365  PBXEB9ZQ7HHCFXYG      36.0  2015-11-19 17:29:21.000              358
# 6366  NKCEAGXHRYTNTMG7      27.0  2015-12-08 04:19:33.000              452
# 6367  CAGE53FSAFWZRHFF      11.0  2016-01-20 19:45:35.000               58
#
# ...

# %% [markdown]
# - Stall_No  should be int
# - min price is int
# - drop Product_id
# - drop instock_date
# - drop customer name
# - discount avail fill 0
# - Max price fill mean

# %%
df.describe()
# Out:
#           Stall_no  Market_Category        Grade       Demand  Discount_avail  \
# count  6363.000000      6368.000000  6368.000000  6368.000000     6330.000000
# mean     25.309445       199.340609     0.643687    50.921168        0.140442
# std      14.328980       170.275570     1.025092    29.091922        0.347473
# min       1.000000         0.000000     0.000000     1.000000        0.000000
# 25%      13.000000        55.000000     0.000000    26.000000        0.000000
# 50%      25.000000       132.000000     0.000000    51.000000        0.000000
# 75%      37.000000       403.000000     2.000000    76.000000        0.000000
# max      50.000000       471.000000     3.000000   100.000000        1.000000
#
#          charges_1  charges_2 (%)  Minimum_price  Maximum_price  Selling_Price
# count  6170.000000    6163.000000    6330.000000    6025.000000    6327.000000
# mean    264.514100      10.146195    3531.349763    6432.545892    4563.242592
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6368 entries, 0 to 6367
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_id        6368 non-null   object
#  1   Stall_no          6363 non-null   float64
#  2   instock_date      6368 non-null   object
#  3   Market_Category   6368 non-null   int64
#  4   Customer_name     6157 non-null   object
#  5   Loyalty_customer  6368 non-null   object
#  6   Product_Category  6368 non-null   object
#  7   Grade             6368 non-null   int64
#  8   Demand            6368 non-null   int64
#  9   Discount_avail    6330 non-null   float64
#  10  charges_1         6170 non-null   float64
#  11  charges_2 (%)     6163 non-null   float64
#  12  Minimum_price     6330 non-null   float64
#  13  Maximum_price     6025 non-null   float64
#  14  Selling_Price     6327 non-null   float64
# dtypes: float64(7), int64(3), object(5)
# memory usage: 746.4+ KB

# %%
df['Demand'].unique()
# Out:
# array([ 68,  51,  10,  48,  35,  49,  57,  67,  53,  84,   6,  22,  38,
#         39,  16,  74,  29,  56,   7,  72,  93,  81,   8,  80,  27,  44,
#         66,  23,  19,  85,  12,  61,  45,  40,  88,  71,  34,  31,  15,
#         55,  82,  46,  69,  14,  41,  60,  63,  87,  52,  28,  77,  21,
#         64,  95,  89,  32,  76,  73,  86,  70,  17,  75,  79,  43,  47,
#          9,   1,  91,   5,  65,  97,  94,  78,  90,  18,   2,  36,  50,
#         30,  58,  99,  24,  98,  96,  42,  25,  62,   4,  20,  59,  13,
#        100,  37,  92,  33,  83,  54,  26,  11,   3], dtype=int64)

# %%
df['Product_Category'].unique()
# Out:
# array(['Fashion', 'Child_care', 'Educational', 'Repair', 'Technology',
#        'Cosmetics', 'Hospitality', 'Organic', 'Pet_care', 'Home_decor'],
#       dtype=object)

# %%
df['Grade'].unique()
# Out:
# array([1, 0, 2, 3], dtype=int64)

# %%
df['Discount_avail'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
df['Discount_avail'].fillna(0,inplace=True)

# %%
x=df['Maximum_price'].mean()
df['Maximum_price'].fillna(x,inplace=True)

y=df['Minimum_price'].mean()
df['Minimum_price'].fillna(x,inplace=True)

a=df['charges_2 (%)'].mean()
df['charges_2 (%)'].fillna(a,inplace=True)

a1=df['charges_1'].mean()
df['charges_1'].fillna(a1,inplace=True)

# %%
df.drop('Product_id',axis=1,inplace=True)
df.drop('Customer_name',axis=1,inplace=True)
df.drop('instock_date',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Stall_no             5
# Market_Category      0
# Loyalty_customer     0
# Product_Category     0
# Grade                0
# Demand               0
# Discount_avail       0
# charges_1            0
# charges_2 (%)        0
# Minimum_price        0
# Maximum_price        0
# Selling_Price       41
# dtype: int64

# %%
df.loc[df['Stall_no'].isnull()]
# Out:
#       Stall_no  Market_Category Loyalty_customer Product_Category  Grade  \
# 557        NaN              151              Yes          Fashion      0
# 2825       NaN              469              No       Hospitality      0
# 3034       NaN              469              Yes           Repair      0
# 4622       NaN               24              No        Home_decor      0
# 4625       NaN              458              Yes          Organic      0
#
#       Demand  Discount_avail  charges_1  charges_2 (%)  Minimum_price  \
# 557       57             0.0      358.0           15.0          715.0
# 2825      99             0.0      321.0           14.0         3196.0
# 3034      90             0.0      251.0            2.0         3605.0
# 4622       2             0.0      284.0           15.0         3402.0
# 4625      86             0.0      119.0            8.0         9481.0
#
#       Maximum_price  Selling_Price
# 557     3433.000000    2419.525296
# ...

# %%
df['Stall_no'].describe()
# Out:
# count    6363.000000
# mean       25.309445
# std        14.328980
# min         1.000000
# 25%        13.000000
# 50%        25.000000
# 75%        37.000000
# max        50.000000
# Name: Stall_no, dtype: float64

# %%
df.dropna(axis=0,inplace=True)

# %%
from sklearn import preprocessing
le1= preprocessing.LabelEncoder()

# %%
df['Loyalty_customer']=le1.fit_transform(df['Loyalty_customer'])
df['Product_Category']=le1.fit_transform(df['Product_Category'])

# %%
df
# Out:
#       Stall_no  Market_Category  Loyalty_customer  Product_Category  Grade  \
# 0         37.0                2                 1                 3      1
# 1         38.0               24                 1                 3      0
# 2          9.0              447                 1                 0      0
# 3         50.0               23                 1                 2      2
# 4          7.0               63                 1                 8      1
# ...        ...              ...               ...               ...    ...
# 6363      17.0               24                 1                 9      0
# 6364      21.0               55                 1                 0      0
# 6365      36.0              358                 0                 8      3
# 6366      27.0              452                 1                 8      0
# 6367      11.0               58                 1                 9      0
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
y=df['Selling_Price']

# %%
x=df.drop('Selling_Price',axis=1)

# %%
x
# Out:
#       Stall_no  Market_Category  Loyalty_customer  Product_Category  Grade  \
# 0         37.0                2                 1                 3      1
# 1         38.0               24                 1                 3      0
# 2          9.0              447                 1                 0      0
# 3         50.0               23                 1                 2      2
# 4          7.0               63                 1                 8      1
# ...        ...              ...               ...               ...    ...
# 6363      17.0               24                 1                 9      0
# 6364      21.0               55                 1                 0      0
# 6365      36.0              358                 0                 8      3
# 6366      27.0              452                 1                 8      0
# 6367      11.0               58                 1                 9      0
#
# ...

# %%
y
# Out:
# 0        4185.947700
# 1        9271.490256
# 2        6785.701362
# 3       13028.917824
# 4         906.553935
#             ...
# 6363    10277.520192
# 6364     4501.837200
# 6365    10218.878775
# 6366     5359.493997
# 6367     5220.013568
# Name: Selling_Price, Length: 6322, dtype: float64

# %% [markdown]
# from sklearn.linear_model import LinearRegression
# from sklearn.linear_model import LogisticRegression

# %% [markdown]
# from sklearn.linear_model import LogisticRegression
# from sklearn import metrics
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)
# logreg = LogisticRegression()
# logreg.fit(x_train, y_train)

# %%
from sklearn import metrics
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
df['Selling_Price'] = np.log(df['Selling_Price'])
# Out:
# C:\Users\ayush\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
regr = DecisionTreeRegressor(max_depth=100)
regr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=100)

# %%
result = regr.predict(x_test)

# %%
result
# Out:
# array([ 3025.846425 ,  9555.55056  ,  1049.4120483, ...,  1003.419648 ,
#         5343.6042   , 11168.306688 ])

# %%
regr.score(x_test,y_test)
# Out:
# 0.9453004682838622

# %%
test=pd.read_csv('test.csv')

# %%
test
# Out:
#             Product_id  Stall_no             instock_date  Market_Category  \
# 0     SCHE4YSTDVPVZVXW      39.0  2016-01-13 07:45:08.000              205
# 1     ACCEGCATKHNRXUHW      49.0  2015-08-23 20:37:05.000                3
# 2     NKCE6GJ5XVJDXNNZ       1.0  2015-11-14 18:12:39.000              183
# 3     NKCEB8BK3ZXDHDHM       8.0  2015-11-21 04:56:19.000              358
# 4     TOPEFDXSAHRNPF94      33.0  2015-05-06 15:09:46.000              167
# ...                ...       ...                      ...              ...
# 3425  BBAE9K7BXFUTDNBK       9.0  2015-08-15 21:17:17.000               58
# 3426  RTRDYPA4PJHCJCGF      30.0  2015-12-04 01:51:47.000              358
# 3427  TUNE8FWQBS7TVVT7      14.0  2016-03-28 20:55:47.000              106
# 3428  NKCEGMUABCRGUZPE       1.0  2015-05-23 07:41:36.000              104
# 3429  RNGE7M92KAQWUBCS       3.0  2015-08-16 22:19:46.000              165
#
# ...

# %%
test['Discount_avail'].fillna(0,inplace=True)

x=test['Maximum_price'].mean()
test['Maximum_price'].fillna(x,inplace=True)

y=test['Minimum_price'].mean()
test['Minimum_price'].fillna(x,inplace=True)

a=test['charges_2 (%)'].mean()
test['charges_2 (%)'].fillna(a,inplace=True)

a1=df['charges_1'].mean()
test['charges_1'].fillna(a1,inplace=True)

# %%
test
# Out:
#             Product_id  Stall_no             instock_date  Market_Category  \
# 0     SCHE4YSTDVPVZVXW      39.0  2016-01-13 07:45:08.000              205
# 1     ACCEGCATKHNRXUHW      49.0  2015-08-23 20:37:05.000                3
# 2     NKCE6GJ5XVJDXNNZ       1.0  2015-11-14 18:12:39.000              183
# 3     NKCEB8BK3ZXDHDHM       8.0  2015-11-21 04:56:19.000              358
# 4     TOPEFDXSAHRNPF94      33.0  2015-05-06 15:09:46.000              167
# ...                ...       ...                      ...              ...
# 3425  BBAE9K7BXFUTDNBK       9.0  2015-08-15 21:17:17.000               58
# 3426  RTRDYPA4PJHCJCGF      30.0  2015-12-04 01:51:47.000              358
# 3427  TUNE8FWQBS7TVVT7      14.0  2016-03-28 20:55:47.000              106
# 3428  NKCEGMUABCRGUZPE       1.0  2015-05-23 07:41:36.000              104
# 3429  RNGE7M92KAQWUBCS       3.0  2015-08-16 22:19:46.000              165
#
# ...

# %% [markdown]
# test.drop('Product_id',axis=1,inplace=True)
# test.drop('Customer_name',axis=1,inplace=True)
# test.drop('instock_date',axis=1,inplace=True)

# %%
test
# Out:
#             Product_id  Stall_no             instock_date  Market_Category  \
# 0     SCHE4YSTDVPVZVXW      39.0  2016-01-13 07:45:08.000              205
# 1     ACCEGCATKHNRXUHW      49.0  2015-08-23 20:37:05.000                3
# 2     NKCE6GJ5XVJDXNNZ       1.0  2015-11-14 18:12:39.000              183
# 3     NKCEB8BK3ZXDHDHM       8.0  2015-11-21 04:56:19.000              358
# 4     TOPEFDXSAHRNPF94      33.0  2015-05-06 15:09:46.000              167
# ...                ...       ...                      ...              ...
# 3425  BBAE9K7BXFUTDNBK       9.0  2015-08-15 21:17:17.000               58
# 3426  RTRDYPA4PJHCJCGF      30.0  2015-12-04 01:51:47.000              358
# 3427  TUNE8FWQBS7TVVT7      14.0  2016-03-28 20:55:47.000              106
# 3428  NKCEGMUABCRGUZPE       1.0  2015-05-23 07:41:36.000              104
# 3429  RNGE7M92KAQWUBCS       3.0  2015-08-16 22:19:46.000              165
#
# ...

# %%
test['Loyalty_customer']=le1.fit_transform(test['Loyalty_customer'])
test['Product_Category']=le1.fit_transform(test['Product_Category'])

# %%
## test.loc[test.index[1107]]
test.at[1107,"Stall_no"]=7

# %%
test.isnull().sum()
# Out:
# Product_id           0
# Stall_no             0
# instock_date         0
# Market_Category      0
# Customer_name       53
# Loyalty_customer     0
# Product_Category     0
# Grade                0
# Demand               0
# Discount_avail       0
# charges_1            0
# charges_2 (%)        0
# Minimum_price        0
# Maximum_price        0
# dtype: int64

# %%
ans=regr.predict(test.drop(columns= ['Product_id','instock_date','Customer_name'],axis=1))

# %%
submission=test

# %%
submission
# Out:
#             Product_id  Stall_no             instock_date  Market_Category  \
# 0     SCHE4YSTDVPVZVXW      39.0  2016-01-13 07:45:08.000              205
# 1     ACCEGCATKHNRXUHW      49.0  2015-08-23 20:37:05.000                3
# 2     NKCE6GJ5XVJDXNNZ       1.0  2015-11-14 18:12:39.000              183
# 3     NKCEB8BK3ZXDHDHM       8.0  2015-11-21 04:56:19.000              358
# 4     TOPEFDXSAHRNPF94      33.0  2015-05-06 15:09:46.000              167
# ...                ...       ...                      ...              ...
# 3425  BBAE9K7BXFUTDNBK       9.0  2015-08-15 21:17:17.000               58
# 3426  RTRDYPA4PJHCJCGF      30.0  2015-12-04 01:51:47.000              358
# 3427  TUNE8FWQBS7TVVT7      14.0  2016-03-28 20:55:47.000              106
# 3428  NKCEGMUABCRGUZPE       1.0  2015-05-23 07:41:36.000              104
# 3429  RNGE7M92KAQWUBCS       3.0  2015-08-16 22:19:46.000              165
#
# ...

# %%
submission['Selling_Price']=ans

# %%
submission
# Out:
#             Product_id  Stall_no             instock_date  Market_Category  \
# 0     SCHE4YSTDVPVZVXW      39.0  2016-01-13 07:45:08.000              205
# 1     ACCEGCATKHNRXUHW      49.0  2015-08-23 20:37:05.000                3
# 2     NKCE6GJ5XVJDXNNZ       1.0  2015-11-14 18:12:39.000              183
# 3     NKCEB8BK3ZXDHDHM       8.0  2015-11-21 04:56:19.000              358
# 4     TOPEFDXSAHRNPF94      33.0  2015-05-06 15:09:46.000              167
# ...                ...       ...                      ...              ...
# 3425  BBAE9K7BXFUTDNBK       9.0  2015-08-15 21:17:17.000               58
# 3426  RTRDYPA4PJHCJCGF      30.0  2015-12-04 01:51:47.000              358
# 3427  TUNE8FWQBS7TVVT7      14.0  2016-03-28 20:55:47.000              106
# 3428  NKCEGMUABCRGUZPE       1.0  2015-05-23 07:41:36.000              104
# 3429  RNGE7M92KAQWUBCS       3.0  2015-08-16 22:19:46.000              165
#
# ...

# %%
test[test.Selling_Price<0]
# Out:
#             Product_id  Stall_no             instock_date  Market_Category  \
# 17    RNGEB2PG3Q5RKDW6      43.0  2015-05-06 16:11:55.000                0
# 155   TOPEEEPVYHHF9HGW      20.0  2015-05-06 15:21:38.000                0
# 376   ACCE6P3BBZD72UJ6      17.0  2015-08-16 19:15:09.000               14
# 730   TCVEHSMFHCPGH9QJ      50.0  2015-05-09 16:19:58.000               14
# 872   BRAEAM5DR9NS5XPE      17.0  2015-08-19 19:21:35.000              104
# 1653  WATEHZN5BG4SUKBY      33.0  2015-11-12 12:21:46.000              469
# 2026  DREEFFG5PA6AVFH9      48.0  2015-11-13 14:05:15.000               63
# 2134  NKCEDCT93M9UCFF4      33.0  2015-11-21 03:54:33.000              104
# 2136  CRTECN2QTARWPXSU      39.0  2015-09-26 14:23:58.000              441
# 2338  SGLEGBV4QFHTNHE2      31.0  2016-03-29 00:03:22.000              224
# 2436  JUMEHGYX4SXZB5K4      40.0  2016-02-21 21:39:21.000               57
# ...

# %%
submission.to_csv('Final.csv')

# %%
a2=pd.read_csv("Final.csv")

# %%
a2.loc[a2.index[1107]]
# Out:
# Unnamed: 0                             1107
# Product_id                 BRAECFAQXWGHUZDQ
# Stall_no                                7.0
# instock_date        2015-08-19 18:36:26.000
# Market_Category                         320
# Customer_name                          Deon
# Loyalty_customer                          1
# Product_Category                          3
# Grade                                     0
# Demand                                    4
# Discount_avail                            0
# charges_1                             395.0
# charges_2 (%)                          17.0
# Minimum_price                         365.0
# Maximum_price                          2401
# Selling_Price                    1596.76488
# Name: 1107, dtype: object

# %%
a2[a2['Selling_Price']>0]
# Out:
#       Unnamed: 0        Product_id  Stall_no             instock_date  \
# 0              0  SCHE4YSTDVPVZVXW      39.0  2016-01-13 07:45:08.000
# 1              1  ACCEGCATKHNRXUHW      49.0  2015-08-23 20:37:05.000
# 2              2  NKCE6GJ5XVJDXNNZ       1.0  2015-11-14 18:12:39.000
# 3              3  NKCEB8BK3ZXDHDHM       8.0  2015-11-21 04:56:19.000
# 4              4  TOPEFDXSAHRNPF94      33.0  2015-05-06 15:09:46.000
# ...          ...               ...       ...                      ...
# 3425        3425  BBAE9K7BXFUTDNBK       9.0  2015-08-15 21:17:17.000
# 3426        3426  RTRDYPA4PJHCJCGF      30.0  2015-12-04 01:51:47.000
# 3427        3427  TUNE8FWQBS7TVVT7      14.0  2016-03-28 20:55:47.000
# 3428        3428  NKCEGMUABCRGUZPE       1.0  2015-05-23 07:41:36.000
# 3429        3429  RNGE7M92KAQWUBCS       3.0  2015-08-16 22:19:46.000
#
#       Market_Category Customer_name  Loyalty_customer  Product_Category  \
# ...
